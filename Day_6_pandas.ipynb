# %%
import pandas as pd

# %%
df = pd.DataFrame({'Employee':['Alice', 'Bob', 'Charlie', 'David'],
                   'Department':['IT', 'HR', 'FINANCE','IT'],
                   'Salary':[60000, 50000, 70000, 65000]})

df
# Out:
#   Employee Department  Salary
# 0    Alice         IT   60000
# 1      Bob         HR   50000
# 2  Charlie    FINANCE   70000
# 3    David         IT   65000

# %%
data_list = [['Alice', 25, 50000], ['Bob', 30, 60000], ['Charlie', 22, 45000]]
data_list
# Out:
# [['Alice', 25, 50000], ['Bob', 30, 60000], ['Charlie', 22, 45000]]

# %%
df_list = pd.DataFrame(data_list)
df_list
# Out:
#          0   1      2
# 0    Alice  25  50000
# 1      Bob  30  60000
# 2  Charlie  22  45000

# %%
columns = ['Name', 'Age', 'Salary']
df_list_col = pd.DataFrame(data_list,columns=columns)
df_list_col
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   22   45000

# %%
df_list_col.shape
# Out:
# (3, 3)

# %%
df_list_col.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df_list_col.dtypes
# Out:
# Name        str
# Age       int64
# Salary    int64
# dtype: object

# %%
df_list_col.head()
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   22   45000

# %%
df_list_col.tail()
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   22   45000

# %%
df_list_col['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: str

# %%
df_list_col['Salary']
# Out:
# 0    50000
# 1    60000
# 2    45000
# Name: Salary, dtype: int64

# %%
df_list_col[['Name','Salary']]
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   45000

# %%
df_list_col['Salary'].mean()
# Out:
# np.float64(51666.666666666664)

# %%
df_list_col['Salary'].max()
# Out:
# np.int64(60000)

# %%
df_list_col['Salary'].min()
# Out:
# np.int64(45000)

# %%
df1 = pd.read_csv('housing.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df1 = pd.read_csv('housing.csv')
#
# NameError: name 'pd' is not defined

# %%
df1
