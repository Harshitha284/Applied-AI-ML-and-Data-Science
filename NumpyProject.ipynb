# %%
import numpy as np
battery_capacity = np.array([40, 42, 38, 45, 41, 39, 44, 43, 37, 46]) #KWh
distance_travelled = np.array([280, 300, 260, 330, 290, 270, 320, 310, 250, 340]) # km
charging_time = np.array([6.5, 6.8, 6.2, 7.1, 6.6, 6.3, 7.0, 6.9, 6.1, 7.2]) # hours
battery_tempature = np.array([35, 38, 34, 42, 37, 36, 41, 39, 33, 43]) # Degree C

# %%
# Understanding the dataset using the Attribute
battery_capacity.shape
battery_capacity.size
battery_capacity.ndim
# Out:
# 1

# %%
# Calculating Efficiency

efficiency = distance_travelled / battery_capacity
print(efficiency)
# Out:
# [7.         7.14285714 6.84210526 7.33333333 7.07317073 6.92307692
#  7.27272727 7.20930233 6.75675676 7.39130435]

# %%
np.max(efficiency)
# Out:
# np.float64(7.391304347826087)

# %%
np.min(efficiency)
# Out:
# np.float64(6.756756756756757)

# %%
np.mean(efficiency)
# Out:
# np.float64(7.0944634097024135)

# %%
#identifying inefficient vehicles
#Battery Overheating Risk Detection
#Vehicles needing immediate Maintenance
#Slicing- Recent Vehicle analysis
#Performance Improvement Simulation
# Final Management summary
